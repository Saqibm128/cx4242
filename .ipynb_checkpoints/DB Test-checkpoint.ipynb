# %%
import sqlalchemy
import pandas as pd
import numpy as np

# %%
engine = sqlalchemy.create_engine("mysql://admin:M0ZtDjLgAmj8D0LzAksT@cx4242.c55yrwcgiytm.us-east-1.rds.amazonaws.com/cx4242")
conn = engine.connect()

# %%
pd.read_sql("EXTRACT(ISOYEAR FROM starttime) AS isoyear FROM citibike ORDER BY starttime;", conn)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1248                     self.dialect.do_execute(
# -> 1249                         cursor, statement, parameters, context
#    1250                     )
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     579     def do_execute(self, cursor, statement, parameters, context=None):
# --> 580         cursor.execute(statement, parameters)
#     581
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/MySQLdb/cursors.py in execute(self, query, args)
#     208         assert isinstance(query, (bytes, bytearray))
# --> 209         res = self._query(query)
#     210         return res
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/MySQLdb/cursors.py in _query(self, q)
#     314         self._result = None
# --> 315         db.query(q)
#     316         self._do_get_result(db)
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/MySQLdb/connections.py in query(self, query)
#     225             query = bytes(query)
# --> 226         _mysql.connection.query(self, query)
#     227
#
# ProgrammingError: (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'EXTRACT(ISOYEAR FROM starttime) AS isoyear FROM citibike ORDER BY starttime' at line 1")
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-47-4be6736c648f> in <module>
# ----> 1 pd.read_sql("EXTRACT(ISOYEAR FROM starttime) AS isoyear FROM citibike ORDER BY starttime;", conn)
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     434             coerce_float=coerce_float,
#     435             parse_dates=parse_dates,
# --> 436             chunksize=chunksize,
#     437         )
#     438
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1216         args = _convert_params(sql, params)
#    1217
# -> 1218         result = self.execute(*args)
#    1219         columns = result.keys()
#    1220
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1085     def execute(self, *args, **kwargs):
#    1086         """Simple passthrough to SQLAlchemy connectable"""
# -> 1087         return self.connectable.execute(*args, **kwargs)
#    1088
#    1089     def read_table(
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/sqlalchemy/engine/base.py in execute(self, object_, *multiparams, **params)
#     980         """
#     981         if isinstance(object_, util.string_types[0]):
# --> 982             return self._execute_text(object_, multiparams, params)
#     983         try:
#     984             meth = object_._execute_on_connection
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_text(self, statement, multiparams, params)
#    1153             parameters,
#    1154             statement,
# -> 1155             parameters,
#    1156         )
#    1157         if self._has_events or self.engine._has_events:
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1251         except BaseException as e:
#    1252             self._handle_dbapi_exception(
# -> 1253                 e, statement, parameters, cursor, context
#    1254             )
#    1255
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1471                 util.raise_from_cause(newraise, exc_info)
#    1472             elif should_wrap:
# -> 1473                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1474             else:
#    1475                 util.reraise(*exc_info)
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     396     exc_type, exc_value, exc_tb = exc_info
#     397     cause = exc_value if exc_value is not exception else None
# --> 398     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     399
#     400
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     150             value.__cause__ = cause
#     151         if value.__traceback__ is not tb:
# --> 152             raise value.with_traceback(tb)
#     153         raise value
#     154
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1247                 if not evt_handled:
#    1248                     self.dialect.do_execute(
# -> 1249                         cursor, statement, parameters, context
#    1250                     )
#    1251         except BaseException as e:
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     578
#     579     def do_execute(self, cursor, statement, parameters, context=None):
# --> 580         cursor.execute(statement, parameters)
#     581
#     582     def do_execute_no_params(self, cursor, statement, context=None):
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/MySQLdb/cursors.py in execute(self, query, args)
#     207
#     208         assert isinstance(query, (bytes, bytearray))
# --> 209         res = self._query(query)
#     210         return res
#     211
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/MySQLdb/cursors.py in _query(self, q)
#     313         db = self._get_db()
#     314         self._result = None
# --> 315         db.query(q)
#     316         self._do_get_result(db)
#     317         self._post_get_result()
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/MySQLdb/connections.py in query(self, query)
#     224         if isinstance(query, bytearray):
#     225             query = bytes(query)
# --> 226         _mysql.connection.query(self, query)
#     227
#     228     def _bytes_literal(self, bs):
#
# ProgrammingError: (MySQLdb._exceptions.ProgrammingError) (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'EXTRACT(ISOYEAR FROM starttime) AS isoyear FROM citibike ORDER BY starttime' at line 1")
# [SQL: EXTRACT(ISOYEAR FROM starttime) AS isoyear FROM citibike ORDER BY starttime;]
# (Background on this error at: http://sqlalche.me/e/f405)

# %%
pd.read_sql("DESCRIBE citibike", conn)
# Out:
#                       Field        Type Null  Key Default Extra
# 0                     index  bigint(20)  YES  MUL    None
# 1              tripduration  bigint(20)  YES         None
# 2                 starttime        text  YES         None
# 3                  stoptime        text  YES         None
# 4          start station id  bigint(20)  YES         None
# 5        start station name        text  YES         None
# 6    start station latitude      double  YES         None
# 7   start station longitude      double  YES         None
# 8            end station id  bigint(20)  YES         None
# 9          end station name        text  YES         None
# 10     end station latitude      double  YES         None
# 11    end station longitude      double  YES         None
# 12                   bikeid  bigint(20)  YES         None
# 13                 usertype        text  YES         None
# 14               birth year  bigint(20)  YES         None
# 15                   gender  bigint(20)  YES         None

# %%
pd.read_sql("SHOW TABLES", conn)
# Out:
#   Tables_in_cx4242
# 0        OSM_nodes
# 1         OSM_ways
# 2         citibike
# 3             uber

# %%
pd.read_sql("SELECT * from uber limit 5", conn)
# Out:
#    year  month  day  hour                time  \
# 0  2019      4   26    11 2019-04-26 15:00:00
# 1  2019      4   26    18 2019-04-26 22:00:00
# 2  2019      4   20    16 2019-04-20 20:00:00
# 3  2019      4   28    12 2019-04-28 16:00:00
# 4  2019      4    3    18 2019-04-03 22:00:00
#
#                                  segment_id  \
# 0  182d8ea1503e2c6687f1c49a692e84ef3212b1e3
# 1  182d8ea1503e2c6687f1c49a692e84ef3212b1e3
# 2  182d8ea1503e2c6687f1c49a692e84ef3212b1e3
# 3  182d8ea1503e2c6687f1c49a692e84ef3212b1e3
# 4  182d8ea1503e2c6687f1c49a692e84ef3212b1e3
#
#                           start_junction_id  \
# 0  cd8b7c3fcc1ba531b0012611d40390ebd73fd05e
# 1  cd8b7c3fcc1ba531b0012611d40390ebd73fd05e
# 2  cd8b7c3fcc1ba531b0012611d40390ebd73fd05e
# 3  cd8b7c3fcc1ba531b0012611d40390ebd73fd05e
# 4  cd8b7c3fcc1ba531b0012611d40390ebd73fd05e
#
#                             end_junction_id  speed_mph_mean  speed_mph_stddev
# 0  3bdb3c6720ac8ed56abe2b7382db21b05bb8a1bc          28.272             6.031
# 1  3bdb3c6720ac8ed56abe2b7382db21b05bb8a1bc          26.155             3.738
# 2  3bdb3c6720ac8ed56abe2b7382db21b05bb8a1bc          23.024             6.918
# 3  3bdb3c6720ac8ed56abe2b7382db21b05bb8a1bc          27.725             2.968
# 4  3bdb3c6720ac8ed56abe2b7382db21b05bb8a1bc          25.429             4.516

# %%
pd.read_sql("select * from OSM_nodes limit 5", conn)
# Out:
#                                 junction_id osm_node_id
# 0  c2584dab13fc7e96dc9a3b3c59cc7f7a2977db16  4374613431
# 1  0de9ea3af5a8528fd39e967f754a8d99a3ad263a    42830605
# 2  63365b0798cfdd824caa5f67175a75bda00ada9d  4205184438
# 3  2772fb90b5fa187c96bff4abe57bfaedb10d3484    42428024
# 4  13c7ebb4db8f7f4557d361cac1afcec1e607d2d3  3788308925

# %%
pd.read_sql("SELECT * from uber \
            join (select junction_id as start_junction_id, osm_node_id as start_osm_node from OSM_nodes) as start_osm_nodes\
                on  start_osm_nodes.start_junction_id=uber.start_junction_id \
            join (select junction_id as end_junction_id, osm_node_id as end_osm_node from OSM_nodes) as end_osm_nodes \
                on  end_osm_nodes.end_junction_id=uber.end_junction_id \
             limit 5", conn)
